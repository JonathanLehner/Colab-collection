# %% [markdown]
# <a href="https://colab.research.google.com/github/JonathanLehner/Colab-collection/blob/master/ATEN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Adaptive Temporal Encoding Network for Video Instance-level Human Parsing
#
# https://github.com/HCPLab-SYSU/ATEN

# %%
import os
from os.path import exists, join, basename

project_name = "ATEN"
if not exists(project_name):
  # clone and install
  # !git clone -q https://github.com/HCPLab-SYSU/ATEN.git
  # !cd $project_name && cd keras_convGRU && python setup.py install
  
import sys
sys.path.append(project_name)
# Out:
# running install
# running bdist_egg
# running egg_info
# creating Keras.egg-info
# writing Keras.egg-info/PKG-INFO
# writing dependency_links to Keras.egg-info/dependency_links.txt
# writing requirements to Keras.egg-info/requires.txt
# writing top-level names to Keras.egg-info/top_level.txt
# writing manifest file 'Keras.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'Keras.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/keras
# copying keras/models.py -> build/lib/keras
# copying keras/activations.py -> build/lib/keras
# copying keras/regularizers.py -> build/lib/keras
# copying keras/optimizers.py -> build/lib/keras
# copying keras/__init__.py -> build/lib/keras
# copying keras/objectives.py -> build/lib/keras
# copying keras/constraints.py -> build/lib/keras
# copying keras/metrics.py -> build/lib/keras
# ...

# %%
#from https://yangcha.github.io/Install-CUDA8/
# !wget http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1604/x86_64/cuda-repo-ubuntu1604_8.0.61-1_amd64.deb
# !wget http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64/libcudnn6_6.0.21-1%2Bcuda8.0_amd64.deb
# !wget http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64/libcudnn6-dev_6.0.21-1%2Bcuda8.0_amd64.deb
# !sudo dpkg -i cuda-repo-ubuntu1604_8.0.61-1_amd64.deb
# !sudo dpkg -i libcudnn6_6.0.21-1+cuda8.0_amd64.deb
# !sudo dpkg -i libcudnn6-dev_6.0.21-1+cuda8.0_amd64.deb
# !sudo apt-get update
# !sudo apt-get install cuda=8.0.61-1
# !sudo apt-get install libcudnn6-dev
# Out:
# --2019-05-03 12:53:16--  http://developer.download.nvidia.com/compute/cuda/repos/ubuntu1604/x86_64/cuda-repo-ubuntu1604_8.0.61-1_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 192.229.211.70, 2606:2800:21f:3aa:dcf:37b:1ed6:1fb
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|192.229.211.70|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2690 (2.6K) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1604_8.0.61-1_amd64.deb’
#
# cuda-repo-ubuntu160 100%[===================>]   2.63K  --.-KB/s    in 0s
#
# 2019-05-03 12:53:17 (382 MB/s) - ‘cuda-repo-ubuntu1604_8.0.61-1_amd64.deb’ saved [2690/2690]
#
# --2019-05-03 12:53:18--  http://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1604/x86_64/libcudnn6_6.0.21-1%2Bcuda8.0_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 192.229.211.70, 2606:2800:21f:3aa:dcf:37b:1ed6:1fb
# ...

# %%
# !export PATH=/usr/local/cuda-8.0/bin${PATH:+:${PATH}}
# !export LD_LIBRARY_PATH=/usr/local/cuda-8.0/lib64${LD_LIBRARY_PATH:+:${LD_LIBRARY_PATH}}

# %%
# !pip uninstall tensorflow # delete preinstalled tensorflow
# !pip install --ignore-installed --upgrade tensorflow-gpu==1.4.1 #according to the repo 1.3
#below is the issue https://github.com/sampepose/flownet2-tf/issues/17 
#also note https://stackoverflow.com/questions/50622525/which-tensorflow-and-cuda-version-combinations-are-compatible
import tensorflow as tf
print(tf.__version__)

# %%
% cd /content/ATEN/keras_convGRU
# !pip uninstall keras
# !python setup.py install

# %%
# %cd /content/ATEN
# !sudo add-apt-repository ppa:ubuntu-toolchain-r/test
# !sudo apt-get update
# !sudo apt install gcc-4.8 g++-4.8
# !sudo update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-4.8 60 --slave /usr/bin/g++ g++ /usr/bin/g++-4.8

# %%
import tensorflow as tf; print(tf.sysconfig.get_include())

# %%
#https://github.com/zengarden/light_head_rcnn/issues/9
# !find /usr/local/lib/ | grep cuda_config.h
import os
#somehow now it only exists in python 2.7
os.environ["CPATH"] = "$CPATH:/usr/local/lib/python2.7/dist-packages/tensorflow/include/external/local_config_cuda/cuda/"

# %%
# %cd /content/ATEN
#https://github.com/HCPLab-SYSU/ATEN/issues/4
#import tensorflow as tf; print(tf.sysconfig.get_include())
# !cd ops && make

# %%
# !mkdir models

'''from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))'''

# !wget https://github.com/JonathanLehner/Colab-collection/releases/download/ATEN/aten_models.zip

# %%
# %cd /content/ATEN
# !mv ./aten_models.zip models/aten_models.zip
# %cd /content/ATEN/models
# !unzip aten_models.zip

# %%
# %cd /content/ATEN
# !pip install pypng

# %%
#seems to be this error https://github.com/sampepose/flownet2-tf/issues/17
# %cd /content/ATEN/
# !python scripts/vip/test_aten.py
#!python scripts/vip/test_parsingrcnn.py

# %%
# from https://stackoverflow.com/questions/48735600/file-download-from-google-drive-to-colaboratory
# !pip install PyDrive

# Oauth
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

gauth = GoogleAuth()
gauth.LocalWebserverAuth()

drive = GoogleDrive(gauth)

# code download
fileId = drive.CreateFile({'id': '1Pk6BpUP5wrPP1l1CVGasPHbDcoOxBmj2'}) #DRIVE_FILE_ID is file id example: 1iytA1n2z4go3uVCwE_vIKouTKyIDjEq
print(fileId['title'])  # UMNIST.zip
fileId.GetContentFile('UMNIST.zip')  # Save Drive file as a local file
