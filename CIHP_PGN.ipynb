# %% [markdown]
# <a href="https://colab.research.google.com/github/JonathanLehner/Colab-collection/blob/master/CIHP_PGN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# this repo needs python 2
# there are some issues with the image preparation --> unexplainable code

# %% [markdown]
# #Part Grouping Network (PGN)
#
# ​
# https://github.com/Engineering-Course/CIHP_PGN

# %%
#https://stackoverflow.com/questions/53417976/import-data-from-shared-google-drive-into-google-colaboratory
#Click on the folder and then click on an option that says "Add to My Drive." The shared folder should now be visible in Google Colab.

# connect to google drive, need to copy auth code from new page
from google.colab import drive
# gdrive not working somehow
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# variables
lip_path = '/content/gdrive/My Drive/LIP'
model_path = '/content/gdrive/My Drive/CIHP_pgn.zip'

# %%
# download repo from Github
import os
from os.path import exists, join, basename

project_name = "CIHP_PGN"
if not exists(project_name):
  # clone
  # !git clone -q https://github.com/Engineering-Course/CIHP_PGN.git

# %%
# %cd /content/CIHP_PGN
# download models
# Inference
# 1. Download the pre-trained model and store in $HOME/checkpoint.
# !mkdir checkpoint
print('cp "{0}" /content/CIHP_PGN/checkpoint/CHIP_pgn.zip'.format(model_path))
os.system('cp "{0}" /content/CIHP_PGN/checkpoint/CHIP_pgn.zip'.format(model_path))
# -j option https://unix.stackexchange.com/questions/72838/unzip-file-contents-but-without-creating-archive-folder
# !cd checkpoint && unzip -j /content/CIHP_PGN/checkpoint/CHIP_pgn.zip 

# 2. Prepare the images and store in $HOME/datasets
# !mkdir checkpoint
# Out:
# /content/CIHP_PGN
# mkdir: cannot create directory ‘checkpoint’: File exists
# cp "/content/gdrive/My Drive/CIHP_pgn.zip" /content/CIHP_PGN/checkpoint/CHIP_pgn.zip
# Archive:  /content/CIHP_PGN/checkpoint/CHIP_pgn.zip
#   inflating: checkpoint
#   inflating: model.ckpt-593292.data-00000-of-00001
#   inflating: model.ckpt-593292.index
#   inflating: model.ckpt-593292.meta
# mkdir: cannot create directory ‘checkpoint’: File exists

# %%
#!cp "/content/gdrive/My Drive/CIHP_pgn.zip" /content/CIHP_PGN/checkpoint/CHIP_pgn.zip

# %%
# load some sample images
# %cd /content/CIHP_PGN/datasets/CIHP/images
#!rm 0002190.png
# !wget -O 0002190.jpg https://cdn-pics.pornhd.com/pornhd/header/category/2_phd_category_big_anal-porn.jpg
# !wget -O 0005008.jpg http://badmilfs.net/wp-content/uploads/2016/06/badmilfs-porn.jpg
# !wget -O 0012008.jpg https://images.nubiles-porn.com/assets/common/images/tubeTourThumbs/147/523/147523/fullSizeCropped_147523.jpg?cacheBust=a0966056
# %cd /content/CIHP_PGN
# Out:
# /content/CIHP_PGN/datasets/CIHP/images
# --2019-05-04 22:47:51--  https://cdn-pics.pornhd.com/pornhd/header/category/2_phd_category_big_anal-porn.jpg
# Resolving cdn-pics.pornhd.com (cdn-pics.pornhd.com)... 64.210.135.68, 64.210.135.70, 64.210.135.72
# Connecting to cdn-pics.pornhd.com (cdn-pics.pornhd.com)|64.210.135.68|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 222592 (217K) [image/jpeg]
# Saving to: ‘0002190.jpg’
#
# 0002190.jpg         100%[===================>] 217.38K  --.-KB/s    in 0.01s
#
# 2019-05-04 22:47:51 (18.5 MB/s) - ‘0002190.jpg’ saved [222592/222592]
#
# --2019-05-04 22:47:54--  http://badmilfs.net/wp-content/uploads/2016/06/badmilfs-porn.jpg
# Resolving badmilfs.net (badmilfs.net)... 5.149.248.193
# Connecting to badmilfs.net (badmilfs.net)|5.149.248.193|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 414272 (405K) [image/jpeg]
# Saving to: ‘0005008.jpg’
#
# ...

# %%
# install octave
# http://wiki.octave.org/Octave_for_Debian_systems
# !sudo apt-get install octave
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   aglfn epstool fonts-droid-fallback fonts-noto-mono ghostscript gnuplot-data
#   gnuplot-qt gsfonts imagemagick-6-common info install-info libamd2
#   libauthen-sasl-perl libcamd2 libccolamd2 libcholmod3 libcolamd2
#   libcupsfilters1 libcupsimage2 libcxsparse3 libdata-dump-perl libemf1
#   libencode-locale-perl libfftw3-single3 libfile-listing-perl libfltk-gl1.3
#   libfltk1.3 libfont-afm-perl libgail-common libgail18 libglpk40
#   libgraphicsmagick++-q16-12 libgraphicsmagick-q16-3 libgs9 libgs9-common
#   libgtk2.0-0 libgtk2.0-bin libgtk2.0-common libhtml-form-perl
#   libhtml-format-perl libhtml-parser-perl libhtml-tagset-perl
# ...

# %%
# !octave
# Out:
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# GNU Octave, version 4.2.2
# Copyright (C) 2018 John W. Eaton and others.
# This is free software; see the source code for copying conditions.
# There is ABSOLUTELY NO WARRANTY; not even for MERCHANTABILITY or
# FITNESS FOR A PARTICULAR PURPOSE.  For details, type 'warranty'.
#
# Octave was configured for "x86_64-pc-linux-gnu".
#
# Additional information about Octave is available at http://www.octave.org.
#
# Please contribute if you find this software useful.
# For more information, visit http://www.octave.org/get-involved.html
#
# Read http://www.octave.org/bugs.html to learn how to submit bug reports.
# For information about changes from previous versions, type 'news'.
#
# octave:1> fff
# error: 'fff' undefined near line 1 column 1
# octave:1> /content/CIHP_pgn/datasets/CIHP/tool/write_edge.m
# parse error:
#
#   syntax error
#
# >>> /content/CIHP_pgn/datasets/CIHP/tool/write_edge.m
#     ^
#
#
# ...

# %%
# prepare images
!
# %cd /content/CIHP_PGN/datasets/CIHP/tool
# !octave 
# %cd /content/CIHP_PGN
#run("/content/CIHP_pgn/datasets/CIHP/tool/write_edge.m")
#run("/content/CIHP_pgn/datasets/CIHP/tool/reverse_label.m")
# Out:
# /content/CIHP_PGN/datasets/CIHP/tool
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# GNU Octave, version 4.2.2
# Copyright (C) 2018 John W. Eaton and others.
# This is free software; see the source code for copying conditions.
# There is ABSOLUTELY NO WARRANTY; not even for MERCHANTABILITY or
# FITNESS FOR A PARTICULAR PURPOSE.  For details, type 'warranty'.
#
# Octave was configured for "x86_64-pc-linux-gnu".
#
# Additional information about Octave is available at http://www.octave.org.
#
# Please contribute if you find this software useful.
# For more information, visit http://www.octave.org/get-involved.html
#
# Read http://www.octave.org/bugs.html to learn how to submit bug reports.
# For information about changes from previous versions, type 'news'.
#
# octave:1> write_edge
# error: textread: could not open '../list/img_list.txt' for reading
# error: called from
#     textread at line 138 column 5
#     write_edge at line 6 column 6
# ...

# %%
# 3. Run test_pgn.py.
# !python test_pgn.py

# %%
# 4. The results are saved in $HOME/output
# 5. Evaluation scripts are in $HOME/evaluation. 
# Copy the groundtruth files (in Instance_ids folder) into $HOME/evaluation/Instance_part_val 


# before you run the script.
